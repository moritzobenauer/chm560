# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
for k in [16, 32, 48, 64]:
    df = pd.read_csv(f'/home/moritz/Projects/chm560/binder_cum_{k}x{k}_{k}x{k}.csv')

    binder_cum = 1 - df['M4'].values / (3*df['M2'].values**2)
    j = df['J'].values

    plt.plot(j, binder_cum, '-o', label=k)

plt.legend()
